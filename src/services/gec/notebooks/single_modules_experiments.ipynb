# %% [markdown]
# # Experimentations

# %%
import logging
import os
import sys

# NOTE: import from root of the project
sys.path.append(os.path.abspath("../../../../"))

from src.services.gec.modules.ontology.loader import OntologyLoader
from src.services.gec.modules.ontology.relation_discoverer import RelationDiscoverer

logging.basicConfig(level=logging.DEBUG)

# %%
ontology_loader = OntologyLoader()
relation_discoverer = RelationDiscoverer(ontology_loader)
# Out:
# 2026-06-23 19:04:46.725 | DEBUG    | src.services.gec.modules.ontology.loader:__new__:27 - Creating new OntologyLoader singleton instance

# %%
relation_discoverer._ensure_properties()
# Out:
# 2026-06-23 19:04:46.751 | INFO     | src.services.gec.modules.ontology.loader:load_graph:52 - Parsing ontology graph from: /Users/incorta/College/GP/baligh/src/services/gec/data/ontology/oas_grammar.owl
# 2026-06-23 19:04:46.946 | INFO     | src.services.gec.modules.ontology.loader:load_graph:59 - Ontology graph loaded successfully. Total triples: 1104
# 2026-06-23 19:04:47.391 | DEBUG    | src.services.gec.modules.ontology.relation_discoverer:_ensure_properties:74 - Loaded 38 ObjectProperties from ontology
# 2026-06-23 19:04:47.391 | DEBUG    | src.services.gec.modules.ontology.relation_discoverer:_ensure_properties:76 -  - اسم_أخوات_ان: http://arabicontology.org/oas_grammar.owl#اسم_منصوب -> http://arabicontology.org/oas_grammar.owl#أخوات_ان
# 2026-06-23 19:04:47.392 | DEBUG    | src.services.gec.modules.ontology.relation_discoverer:_ensure_properties:76 -  - اسم_أخوات_كاد: http://arabicontology.org/oas_grammar.owl#اسم_مرفوع -> http://arabicontology.org/oas_grammar.owl#أخوات_كاد
# ...
